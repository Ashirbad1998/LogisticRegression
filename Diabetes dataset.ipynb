# %% [markdown]
# ### Problem Statement:
# In this project we will specifically focus on predicting Diabetes on the basis of various predictors.

# %% [markdown]
# The data includes features such as age, gender, body mass index (BMI), hypertension, heart disease, smoking history, HbA1c level, and blood glucose level.

# %% [markdown]
# ### Step-1: Import Libraries like Pandas ,matplotlib,Seaborn,warnings

# %%
#Pandas- for Data manipulation and analysis.
import pandas as pd

#Matplotlib- For Data Visualization
import matplotlib.pyplot as plt

#Seaborn-For Data Visualization
import seaborn as sns

#warnings-For avoid warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### Step-2: Load the Dataset

# %%
#Loading Diabetes dataset
df=pd.read_csv(r"C:\Users\Dell\Downloads\imarticus learning\Machine Learning\Kaggle data sets\Csv folder\diabetes_prediction_dataset.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %% [markdown]
# ### Step-3: Exploratory Data Analysis

# %% [markdown]
# Exploratory Data Analysis (EDA), also known as Data Exploration, it is a step in the Data Analysis Process, where a number of techniques are used to better understand the dataset being used.
#
# In this step, we will perform the below operations:
#
# 3.1) understanding Your Variables
#
#     3.1.1) Head of the dataset
#     3.1.2) The shape of the dataset
#     3.1.3) List types of all columns
#     3.1.4) Info of the dataset
#     3.1.5) Summary of the dataset
#
# 3.2) Data Cleaning
#
#     3.2.1) Checking the Duplicates
#     3.2.2) Check the Null values

# %% [markdown]
# ### 3.1.1) Head of the Dataset.
# The head()function will tell you top 5 records in the dataset.By default,Python shows only the top 5 records.
# The head(n)function returns the first n rows for the object based on the postion.

# %%
#Display the top 5 records of the data.
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
#Displays the last 5 records of the data.
df.tail()
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %% [markdown]
# ### 3.1.2) The Shape of the Dataset.
# This shape() function gives number of rows and columns of the dataset.

# %%
#Number of rows and columns
df.shape
# Out:
# (100000, 9)

# %% [markdown]
# No. of rows=100000.
#  No. of columns=9

# %% [markdown]
# ### 3.1.3) List type of all columns
# Using dtypes ,we get list of types of all columns in our dataset.

# %%
# List the type of all the columns
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %% [markdown]
# ### 3.1.4)Info of the Dataset
# Info() is used to check the information about the data and datatypes of each respective attributes and also give you the counts.

# %%
#Finding out if the data sets contains any null values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# ### 3.1.5) Summery of The Dataset
# describe will give the statistical summary.We can clearly seen minimum values,mean values,different percentile values and maximum values.

# %%
#Statistical Summary.
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# ### Numerical Features

# %%
num_features=df.dtypes[df.dtypes!="object"].index
num_features
# Out:
# Index(['age', 'hypertension', 'heart_disease', 'bmi', 'HbA1c_level',
#        'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
len(num_features)
# Out:
# 7

# %%
#Summarize Numerical Features
df[num_features].describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# ### Distribution of categorical features

# %%
cat_features=df.dtypes[df.dtypes=="object"].index
cat_features
# Out:
# Index(['gender', 'smoking_history'], dtype='object')

# %%
len(cat_features)
# Out:
# 2

# %%
#Summarize the categorical Features.
df[cat_features].describe()
# Out:
#         gender smoking_history
# count   100000          100000
# unique       3               6
# top     Female         No Info
# freq     58552           35816

# %% [markdown]
# ### Check the unique labels in the categorical variables.

# %%
#Check the unique labels of the 'gender' variable.
df.gender.unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
#Print the no.of counts for 'gender' variable.
df.gender.value_counts()
# Out:
# Female    58552
# Male      41430
# Other        18
# Name: gender, dtype: int64

# %%
#Check the unique labels of 'smoking_history' variable.
df.smoking_history.unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
#Print the no.of counts for "smoking_history" variable.
df.smoking_history.value_counts()
# Out:
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: smoking_history, dtype: int64

# %%
# or We can run this through loop.
for i in df.columns:
    print(f"name of the column={i}","\n")
    print(df[i].unique(),"\n")
    print(f"no of unique columns=",df[i].nunique())
# Out:
# name of the column=gender
#
# ['Female' 'Male' 'Other']
#
# no of unique columns= 3
# name of the column=age
#
# [80.   54.   28.   36.   76.   20.   44.   79.   42.   32.   53.   78.
#  67.   15.   37.   40.    5.   69.   72.    4.   30.   45.   43.   50.
#  41.   26.   34.   73.   77.   66.   29.   60.   38.    3.   57.   74.
#  19.   46.   21.   59.   27.   13.   56.    2.    7.   11.    6.   55.
#   9.   62.   47.   12.   68.   75.   22.   58.   18.   24.   17.   25.
#   0.08 33.   16.   61.   31.    8.   49.   39.   65.   14.   70.    0.56
#  48.   51.   71.    0.88 64.   63.   52.    0.16 10.   35.   23.    0.64
#   1.16  1.64  0.72  1.88  1.32  0.8   1.24  1.    1.8   0.48  1.56  1.08
#   0.24  1.4   0.4   0.32  1.72  1.48]
#
# no of unique columns= 102
# name of the column=hypertension
#
# [0 1]
#
# no of unique columns= 2
# name of the column=heart_disease
#
# [1 0]
#
# no of unique columns= 2
# name of the column=smoking_history
#
# ...

# %% [markdown]
# ### 3.2) Data Cleaning

# %% [markdown]
# #### 3.2.1) Drop the duplicates
# Check is there any duplicates rows exist then we should remove from the dataframe.

# %%
#check the shape before drop the duplicates.
df.shape
# Out:
# (100000, 9)

# %%
df[df.duplicated()]
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 2756     Male  80.0             0              0         No Info  27.32
# 3272   Female  80.0             0              0         No Info  27.32
# 3418   Female  19.0             0              0         No Info  27.32
# 3939   Female  78.0             1              0          former  27.32
# 3960     Male  47.0             0              0         No Info  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99980  Female  52.0             0              0           never  27.32
# 99985    Male  25.0             0              0         No Info  27.32
# 99989  Female  26.0             0              0         No Info  27.32
# 99990    Male  39.0             0              0         No Info  27.32
# 99995  Female  80.0             0              0         No Info  27.32
#
#        HbA1c_level  blood_glucose_level  diabetes
# 2756           6.6                  159         0
# ...

# %%
df.drop_duplicates(keep="first",inplace=True)

# %%
df.shape
# Out:
# (96146, 9)

# %% [markdown]
# You can see there are 3854 duplicates data and we dropped duplicated data.
#
# before the no of records=100000
#
# after droping the duplicates the no of records=96146

# %%
df.drop("smoking_history",axis=1,inplace=True)

# %%
df
# Out:
#        gender   age  hypertension  heart_disease    bmi  HbA1c_level  \
# 0      Female  80.0             0              1  25.19          6.6
# 1      Female  54.0             0              0  27.32          6.6
# 2        Male  28.0             0              0  27.32          5.7
# 3      Female  36.0             0              0  23.45          5.0
# 4        Male  76.0             1              1  20.14          4.8
# ...       ...   ...           ...            ...    ...          ...
# 99994  Female  36.0             0              0  24.60          4.8
# 99996  Female   2.0             0              0  17.37          6.5
# 99997    Male  66.0             0              0  27.83          5.7
# 99998  Female  24.0             0              0  35.42          4.0
# 99999  Female  57.0             0              0  22.43          6.6
#
#        blood_glucose_level  diabetes
# 0                      140         0
# 1                       80         0
# ...

# %% [markdown]
# ### 3.2.2) Check the null values.
# Using .isnull().sum() function we can see the null values that is present in the every column or not.

# %%
#Count the null values
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %% [markdown]
# There is no null values in the given dataset.

# %% [markdown]
# ### 4)Data Visualization
#     4.1) Histograms
#
# Histograms are one of the most common graphs used to display numeric data.
# distribution of the data --- whether the data is normally distributed or if it's skewed (to the left or right)

# %%
#histogram of each features
df.hist(bins=10,figsize=(10,8))
plt.show()

# %% [markdown]
# ### Boxplot

# %% [markdown]
# Box plot show distributions with respect to categories. with different statistical information like min,max,and different quartiles

# %%
sns.catplot(x="diabetes",y="blood_glucose_level",kind="box",hue="gender",data=df)
plt.show()

# %%
df.groupby(["gender","diabetes"])[["age"]].describe()
# Out:
#                      age
#                    count       mean        std   min    25%   50%   75%   max
# gender diabetes
# Female 0         51714.0  40.739811  21.597617  0.08  24.00  41.0  57.0  80.0
#        1          4447.0  60.947380  14.894589  4.00  52.00  62.0  73.0  80.0
# Male   0         35932.0  38.801977  23.059390  0.08  19.00  40.0  57.0  80.0
#        1          4035.0  60.902354  14.152172  3.00  52.00  62.0  72.0  80.0
# Other  0            18.0  29.555556  16.695270  7.00  18.25  25.0  46.5  55.0

# %%
sns.catplot(x="diabetes",y="age",kind="box",hue="gender",data=df)
plt.show()

# %% [markdown]
# From the above boxplot for Diabetes vs Age we can see that most of the female and male patients have Diabetes at the middle age and some people have diabetes at the lower age

# %%
sns.catplot(x="gender",y="blood_glucose_level",hue="diabetes",kind="box",data=df)

# %%
sns.catplot(x = 'hypertension',y = 'age', kind = 'box', hue = 'gender',data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
new_df=df.copy()

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Converting Categorical variable to Numerical Variable

# %% [markdown]
# Apply 'get_dummies()' Method
#
# This is one of the approach and also an each one to encode Categorical data. pandas get_dummies() method takes categorical feature as an argument. Then it creates a Dummy variable for every label in the feature, such that each dummy variable holds data as 1 or 0.1 indicates the presence of a particular label and 0 indicates the absence of a particular label.

# %%
df1 = pd.get_dummies(new_df,drop_first=True)

# %%
df1.shape
# Out:
# (96146, 9)

# %% [markdown]
# ### Split the dataframe into x & y

# %%
# Separate object for target feature 
y = df1["diabetes"]

# Separate object for Predictors 
X = df1.drop("diabetes",axis=1)

# %%
X.head()
# Out:
#     age  hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level  \
# 0  80.0             0              1  25.19          6.6                  140
# 1  54.0             0              0  27.32          6.6                   80
# 2  28.0             0              0  27.32          5.7                  158
# 3  36.0             0              0  23.45          5.0                  155
# 4  76.0             1              1  20.14          4.8                  155
#
#    gender_Male  gender_Other
# 0            0             0
# 1            0             0
# 2            1             0
# 3            0             0
# 4            1             0

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: diabetes, dtype: int64

# %%
print('X Shape =',X.shape,'\ny Shape =',y.shape)
# Out:
# X Shape = (96146, 8)
# y Shape = (96146,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve,roc_auc_score

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=15)

# %%
LR=LogisticRegression()
LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
train_pred = LR.predict(X_train)
test_pred = LR.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_train,train_pred))
# Out:
# [[60600   772]
#  [ 2264  3666]]

# %%
print(confusion_matrix(y_test,test_pred))
# Out:
# [[25944   348]
#  [  898  1654]]

# %%
print(classification_report(y_train,train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     61372
#            1       0.83      0.62      0.71      5930
#
#     accuracy                           0.95     67302
#    macro avg       0.90      0.80      0.84     67302
# weighted avg       0.95      0.95      0.95     67302

# %%
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     26292
#            1       0.83      0.65      0.73      2552
#
#     accuracy                           0.96     28844
#    macro avg       0.90      0.82      0.85     28844
# weighted avg       0.95      0.96      0.95     28844

# %% [markdown]
# ### Roc Curve

# %%
fpr,tpr,threshold=roc_curve(y_test,test_pred)

# %%
print('roc_auc_score for logistic Regression= ',roc_auc_score(y_test,test_pred))
# Out:
# roc_auc_score for logistic Regression=  0.8174415784722053

# %%
from sklearn.metrics import auc
auc=auc(fpr,tpr)

# %%
plt.subplots(1,figsize=(10,10))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(fpr,tpr,label='auc= {}'.format(auc))
plt.legend(loc='lower right')
plt.plot([0, 1], ls="--")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
