# %% [markdown]
# ### Import necessary Libraries

# %%
import pandas as pd                        #for Data visualization and Data Analysis
import numpy as np                         # for numerical calculation
import matplotlib.pyplot as plt            # for Data visualization
import seaborn as sns                      # for Data visualization
import warnings                            # for removing unwanted warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2)Load The Dataset

# %%
train_data=pd.read_csv(r"C:\Users\Dell\Downloads\imarticus learning\Machine Learning\Kaggle data sets\Csv folder\New\Titanic_dataset\train.csv")

# %%
# top five records
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Dataset Description

# %% [markdown]
# PassengerId= Unique id it have
#
# Survived =   (0 = No, 1 = Yes)
#
# pclass= Ticket class( 1 = 1st, 2 = 2nd, 3 = 3rd)
#
# Name= Passenger name
#
# Sex= it represents Gender column
#
# Age= Age in years
#
# Sibsp= of siblings / spouses aboard the Titanic.
#
# Parch= of parents / children aboard the Titanic.
#
# Ticket=Ticket number
#
# Fare= Passenger fare
#
# Cabin= Cabin number
#
# Embarked= Port of Embarkation C = Cherbourg, Q = Queenstown, S = South ampton

# %%
 train_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Here we can see Age and Cabin and Emarked have null values.(we can drop it or treat the null values based on condition)

# %% [markdown]
# ### 3)Load the Test dataset

# %%
test_data=pd.read_csv(r"C:\Users\Dell\Downloads\imarticus learning\Machine Learning\Kaggle data sets\Csv folder\New\Titanic_dataset\test.csv")

# %%
# top five records 
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data.shape
# Out:
# (418, 11)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# Here we can see Age,Fare and Cabin have null values. same we can drop the null values or impute it based on condition.

# %% [markdown]
# ### 4) EDA [Exploratory Data Analysis]

# %%
#Taking train_data
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#check the duplicates records
train_data[train_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# In train_data we don't have duplicates records.

# %%
#check any null values present or not
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#show age null values data
train_data[train_data["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.head(45)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# From above two like train_data.describe() and train_data.head(45) age is varies from 3.0 to 80.0 .
# so we are going to impute age column null values.

# %%
train_data["Age"].fillna(np.random.randint(3.0,81.0),inplace=True)

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Perform Embarked feature columns
train_data[train_data["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df_categorical_feature=train_data.select_dtypes(include="object")
df_categorical_feature
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df_categorical_feature.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
train_data[train_data["Pclass"]==1]["Embarked"].value_counts()
# Out:
# S    127
# C     85
# Q      2
# Name: Embarked, dtype: int64

# %% [markdown]
# Here we can see max people with "1- class" ticket are getting on the ship from South ampton port.
# So we are going to impute the null values with "S" in Emabarked column.

# %%
train_data["Embarked"].fillna("S",inplace=True)

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# Cabin column

# %% [markdown]
# Here we are going to drop the cabin column.Because their no relation between servived and cabin ,on other hand it's having lot of null values.So it's better to drop the column.

# %%
train_data.drop("Cabin",axis=1,inplace=True)

# %%
#now check null values
train_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Yes All clear

# %% [markdown]
# Ticket Column

# %%
train_data[~train_data["Ticket"].str.isnumeric()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 10            11         1       3
# 12            13         0       3
# ..           ...       ...     ...
# 867          868         0       1
# 874          875         1       2
# 883          884         0       2
# 884          885         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Ticket=[]
for i in train_data["Ticket"]:
    Ticket.append(i.split()[-1])

print("Ticket=",Ticket)
# Out:
# Ticket= ['21171', '17599', '3101282', '113803', '373450', '330877', '17463', '349909', '347742', '237736', '9549', '113783', '2151', '347082', '350406', '248706', '382652', '244373', '345763', '2649', '239865', '248698', '330923', '113788', '349909', '347077', '2631', '19950', '330959', '349216', '17601', '17569', '335677', '24579', '17604', '113789', '2677', '2152', '345764', '2651', '7546', '11668', '349253', '2123', '330958', '23567', '370371', '14311', '2662', '349237', '3101295', '39886', '17572', '2926', '113509', '19947', '31026', '2697', '34651', '2144', '2669', '113572', '36973', '347088', '17605', '2661', '29395', '3464', '3101281', '315151', '33111', '2144', '14879', '2680', '1601', '348123', '349208', '374746', '248738', '364516', '345767', '345779', '330932', '113059', '14885', '3101278', '6608', '392086', '19950', '343275', '343276', '347466', '5734', '2315', '364500', '374910', '17754', '17759', '231919', '244367', '349245', '349215', '35281', '7540', '3101276', '34920
# ...

# %%
train_data["Ticket"]=Ticket

# %% [markdown]
# Here we can see LINE present in the Ticket column which shouldn't be.so impute it

# %%
train_data["Ticket"].replace("LINE","NaN",inplace=True)

# %%
train_data[train_data["Ticket"]=="NaN"]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 179          180         0       3              Leonard, Mr. Lionel  male
# 271          272         1       3     Tornquist, Mr. William Henry  male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  male
# 597          598         0       3              Johnson, Mr. Alfred  male
#
#       Age  SibSp  Parch Ticket  Fare Embarked
# 179  36.0      0      0    NaN   0.0        S
# 271  25.0      0      0    NaN   0.0        S
# 302  19.0      0      0    NaN   0.0        S
# 597  49.0      0      0    NaN   0.0        S

# %%
train_data.drop([179,271,302,597],axis=0,inplace=True)

# %%
train_data[train_data["Ticket"]=="NaN"]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
train_data.reset_index(drop=True,inplace=True)

# %%
train_data["Ticket"].dtype
# Out:
# dtype('O')

# %%
train_data["Ticket"]=train_data.Ticket.astype(int)

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch   Ticket     Fare Embarked
# 0      0    21171   7.2500        S
# 1      0    17599  71.2833        C
# 2      0  3101282   7.9250        S
# 3      0   113803  53.1000        S
# 4      0   373450   8.0500        S

# %%
sns.heatmap(train_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
train_data.hist(bins=10,figsize=(10,10))
plt.show()

# %%
sns.histplot(train_data["Fare"],kde=True)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %% [markdown]
# **Check Any extreme outlier present or not.**

# %%
#Check Outliers
sns.boxplot(train_data["Fare"])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %% [markdown]
# From above figure we can see a extreme outliers present in data.

# %%
train_data[train_data["Fare"]>500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 257          259         1       1                    Ward, Miss. Anna
# 675          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 733          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch  Ticket      Fare Embarked
# 257  female  35.0      0      0   17755  512.3292        C
# 675    male  36.0      0      1   17755  512.3292        C
# 733    male  35.0      0      0   17755  512.3292        C

# %%
train_data.groupby("Pclass")["Fare"].describe()
# Out:
#         count       mean        std     min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0000  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0000  13.00000  14.2500  26.0   73.5000
# 3       487.0  13.787875  11.760718  4.0125   7.75000   8.0500  15.5   69.5500

# %%
# checking the outliers
train_IQR=train_data.groupby("Pclass")["Fare"].describe()['75%']-train_data.groupby("Pclass")["Fare"].describe()['25%']
print('train_IQR =',train_IQR)
train_HE=train_data.groupby("Pclass")["Fare"].describe()['75%']+1.5*train_IQR
print('train_HE =',train_HE)
train_LE=train_data.groupby("Pclass")["Fare"].describe()['25%']-1.5*train_IQR
print('train_LE =',train_LE)
# Out:
# train_IQR = Pclass
# 1    62.57605
# 2    13.00000
# 3     7.75000
# dtype: float64
# train_HE = Pclass
# 1    187.364075
# 2     45.500000
# 3     27.125000
# dtype: float64
# train_LE = Pclass
# 1   -62.940125
# 2    -6.500000
# 3    -3.875000
# dtype: float64

# %%
train_data["Fare"].replace(512.3292,187.3640,inplace=True)

# %%
train_data[train_data["Fare"]>500]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
train_data[train_data["Fare"]==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 262          264         0       1             Harrison, Mr. William  male
# 275          278         0       2       Parkes, Mr. Francis "Frank"  male
# 410          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 463          467         0       2             Campbell, Mr. William  male
# 478          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 629          634         0       1     Parr, Mr. William Henry Marsh  male
# 670          675         0       2        Watson, Mr. Ennis Hastings  male
# 728          733         0       2              Knight, Mr. Robert J  male
# 802          807         0       1            Andrews, Mr. Thomas Jr  male
# 811          816         0       1                  Fry, Mr. Richard  male
# 818          823         0       1   Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch  Ticket  Fare Embarked
# ...

# %% [markdown]
# Now we are going to impute the "Pclass"=1, whose fare are zero (which is absurd) so we can't imput it with lower end(LE) values because it is negative so we can impute with Q1 values of "Pclass"=1.

# %%
train_data["Fare"].replace(0.0,30.9239,inplace=True)

# %%
train_data[train_data["Fare"]==0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %% [markdown]
# Now we are going to impute the "Pclass"=2, whose fare are zero (which is absurd) so we can't imput it with lower end(LE) values because it is negative so we can impute with  Q1 values of "Pclass"=2.

# %%
sns.histplot(train_data.Survived)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Count'>

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
sns.catplot(x="Sex",y="Survived",data=train_data,kind="bar")
plt.show()

# %%
train_data.groupby("Sex")["Survived"].value_counts(normalize=True)*100
# Out:
# Sex     Survived
# female  1           74.203822
#         0           25.796178
# male    0           81.151832
#         1           18.848168
# Name: Survived, dtype: float64

# %% [markdown]
# **By the above graph you can state that 74% of female are survived and 18% of male are survived.**

# %%
sns.catplot(x="Sex",y="Survived",hue="Pclass",data=train_data,kind="bar")
plt.show()

# %%
train_data.groupby(["Sex","Pclass"])["Survived"].value_counts(normalize=True)*100
# Out:
# Sex     Pclass  Survived
# female  1       1           96.808511
#                 0            3.191489
#         2       1           92.105263
#                 0            7.894737
#         3       0           50.000000
#                 1           50.000000
# male    1       0           63.114754
#                 1           36.885246
#         2       0           84.259259
#                 1           15.740741
#         3       0           86.588921
#                 1           13.411079
# Name: Survived, dtype: float64

# %% [markdown]
# By seeing above graph you can state that 96.8% of female Passenger who are in first class were survived and on the second class 92% of female Passenger were survived and 50% of female Passenger were in third class were survived , 36% of Male Passenger were survived who are in first class, 15% of Male Passenger were survived who are in second class, and 13% of Male Passenger were survived who were in Third class

# %% [markdown]
# By seeing above statement you can state that the female passenger with firstclass ticket is almost survived and if the ticket is high class then there is higher probability to survive and the survival rate of female is higher than male class

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch   Ticket     Fare Embarked
# 0      0    21171   7.2500        S
# 1      0    17599  71.2833        C
# 2      0  3101282   7.9250        S
# 3      0   113803  53.1000        S
# 4      0   373450   8.0500        S

# %%
train_data.groupby(["Sex","Pclass"])["Survived"].value_counts()
# Out:
# Sex     Pclass  Survived
# female  1       1            91
#                 0             3
#         2       1            70
#                 0             6
#         3       0            72
#                 1            72
# male    1       0            77
#                 1            45
#         2       0            91
#                 1            17
#         3       0           297
#                 1            46
# Name: Survived, dtype: int64

# %%
train_data.groupby("Sex")["Pclass"].value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         343
#         1         122
#         2         108
# Name: Pclass, dtype: int64

# %% [markdown]
# Male Passengers are more than female passengers in different classes.

# %%
sns.catplot(x="Embarked",kind="count",data=train_data,hue="Pclass")
plt.show()

# %% [markdown]
# Maximum passengers are boarded from S port means South ampton port.

# %% [markdown]
# **Now Will perform point plot.**

# %%
sns.catplot(x="Sex",y="Survived",data=train_data,hue="Pclass",kind="point")
plt.show()

# %% [markdown]
# By seeing the above graph we can state that there is higher chances of survival rate for female passengers compared to male passengers.

# %% [markdown]
# #### Check Dataset

# %%
#check data is balanced one or unbalaced one.
sns.countplot(train_data["Survived"])
plt.show()

# %% [markdown]
# By seeing the picture we can say that is a balanced dataset.We can build the model.

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch   Ticket     Fare Embarked
# 0      0    21171   7.2500        S
# 1      0    17599  71.2833        C
# 2      0  3101282   7.9250        S
# 3      0   113803  53.1000        S
# 4      0   373450   8.0500        S

# %% [markdown]
# **Remove Feature for better building model.**

# %%
sns.heatmap(train_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above figure we can state that correlation between "PassengerId","Ticket" with Target variable "Survived" is less.(Means they are not giving much information about the target variable).So we can drop two column for better model building.Also we have drop the "Name" column because it is a unique column and its difficult to covert these categorical data to numerical data.

# %%
train_data.drop(["PassengerId","Name","Ticket"],axis=1,inplace=True)

# %%
train_data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
train_data.shape
# Out:
# (887, 8)

# %% [markdown]
# **Encoding technique**

# %%
# backup data
train_data_backup=train_data.copy(deep=True)

# %%
train_data=pd.get_dummies(train_data,drop_first=True)

# %%
train_data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0         0       3  22.0      1      0   7.2500         1           0
# 1         1       1  38.0      1      0  71.2833         0           0
# 2         1       3  26.0      0      0   7.9250         0           0
# 3         1       1  35.0      1      0  53.1000         0           0
# 4         0       3  35.0      0      0   8.0500         1           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
train_data.shape
# Out:
# (887, 9)

# %%
sns.boxplot(train_data["Fare"])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve,roc_auc_score

# %%
train_data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0         0       3  22.0      1      0   7.2500         1           0
# 1         1       1  38.0      1      0  71.2833         0           0
# 2         1       3  26.0      0      0   7.9250         0           0
# 3         1       1  35.0      1      0  53.1000         0           0
# 4         0       3  35.0      0      0   8.0500         1           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
X = train_data.drop("Survived",axis=1)
y = train_data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=9)

# %%
LR=LogisticRegression()
LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
train_pred = LR.predict(X_train)
test_pred = LR.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_train,train_pred))
# Out:
# [[170   0]
#  [  0 450]]

# %%
print(confusion_matrix(y_test,test_pred))
# Out:
# [[ 75   0]
#  [  0 192]]

# %%
print(classification_report(y_train,train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       170
#            1       1.00      1.00      1.00       450
#
#     accuracy                           1.00       620
#    macro avg       1.00      1.00      1.00       620
# weighted avg       1.00      1.00      1.00       620

# %%
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        75
#            1       1.00      1.00      1.00       192
#
#     accuracy                           1.00       267
#    macro avg       1.00      1.00      1.00       267
# weighted avg       1.00      1.00      1.00       267

# %% [markdown]
# ### Roc Curve

# %%
fpr,tpr,threshold=roc_curve(y_test,test_pred)

# %%
print('roc_auc_score for logistic Regression= ',roc_auc_score(y_test,test_pred))
# Out:
# roc_auc_score for logistic Regression=  1.0

# %%
from sklearn.metrics import auc
auc=auc(fpr,tpr)

# %%
plt.subplots(1,figsize=(10,10))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(fpr,tpr,label='auc= {}'.format(auc))
plt.legend(loc='lower right')
plt.plot([0, 1], ls="--")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# Now we are going to perform for Test Data
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# **Now will perfrom the Preprocessing Technique for Test Data.**

# %%
#EDA

#Age Column
#show age null values data
test_data[test_data["Age"].isnull()]
test_data.describe()
#From above test_data.describe() age is varies from 0.17 to 76.0 . so we are going to impute age column null values.
test_data["Age"].fillna(np.random.randint(0.17,76.0),inplace=True)

#Fare Column
test_data.groupby("Pclass")[["Fare"]].describe()
#From test_data.groupby("Pclass")[["Fare"]].describe() ,impute the "Fare" null value with the Avg of "Pclass"=3
test_data["Fare"].fillna(12.45,inplace=True)

#Cabin Column
#Here we are going to drop the cabin column.Because their no relation between servived and cabin ,on other hand it's having lot of null values.So it's better to drop the column.
test_data.drop("Cabin",axis=1,inplace=True)


sns.heatmap(test_data.corr(),annot=True)
#From the above figure we can state that correlation between "PassengerId","Ticket" with Target variable "Survived" is less.
#(Means they are not giving much information about the target variable).
#So we can drop two column for better model building.Also we have drop the "Name" column because it is a unique column and its difficult to covert these categorical data to numerical data.

test_data.drop(["PassengerId","Name","Ticket"],axis=1,inplace=True)

#shape
test_data.shape


# backup data
test_data_backup=test_data.copy(deep=True)
test_data=pd.get_dummies(test_data,drop_first=True)

# %%
test_data.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S
# 0       3  34.5      0      0   7.8292         1           1           0
# 1       3  47.0      1      0   7.0000         0           0           1
# 2       2  62.0      0      0   9.6875         1           1           0
# 3       3  27.0      0      0   8.6625         1           0           1
# 4       3  22.0      1      1  12.2875         0           0           1

# %%
Predicted_Survived = pd.Series(LR.predict(test_data))

# %%
len(LR.predict(test_data))
# Out:
# 418

# %%
test_data.shape
# Out:
# (418, 8)

# %%
test_data.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S
# 0       3  34.5      0      0   7.8292         1           1           0
# 1       3  47.0      1      0   7.0000         0           0           1
# 2       2  62.0      0      0   9.6875         1           1           0
# 3       3  27.0      0      0   8.6625         1           0           1
# 4       3  22.0      1      1  12.2875         0           0           1

# %%
test_data=pd.read_csv(r"C:\Users\Dell\Downloads\imarticus learning\Machine Learning\Kaggle data sets\Csv folder\New\Titanic_dataset\test.csv")

# %%
# top five records 
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
Predicted_Survived[0:5]
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    1
# dtype: uint8

# %% [markdown]
# **If "Pclass"=3 and "Sex"=male then Survival chance of that passenger is 0 and if "Pclass"=3 and "Sex"=female then Survival chance of that passenger is 1(means Alive) with 95% confidence interval.**
